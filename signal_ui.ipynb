# %%
# %matplotlib inline

from vix_trade_ui import signal_ui
signal_ui.show_ui()

# %%
import  matplotlib.pyplot  as plt

fig,ax = plt.subplots()
t=10

x=range(t)
signal=[1.212 for i in range(t)]
red_line = [1.17 for i in range(len(x))]
yellow_line = [1.20 for i in range(len(x))]
green_line = [1.25 for i in range(len(x))]


plt.plot(x,red_line,"-",label="red",color="red")
plt.plot(x,yellow_line,"-",label="red",color="yellow")
plt.plot(x,green_line,"-",label="red",color="green")
plt.plot(x,signal,"*-",label="signal",color="blue")
plt.show()

# %%
import seaborn as sns
sns.set(style="darkgrid")

# Load an example dataset with long-form data
fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
sns.lineplot(x="timepoint", y="signal",
             hue="region", style="event",
             data=fmri)
